# %%
# show dbs
#create new db
#insert data into this db

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # insert multiple collection/object in single time
# ![image.png](attachment:image.png)

# %% [markdown]
# # update and delete operations
#
# ![image.png](attachment:image.png)
#
#
#
# ![image-2.png](attachment:image-2.png)

# %%
db.dropDatabase()
import a json file in db
Mongoimport "C:\Users\Praveen Sharma\Downloads\students.json" -d collage -c studen -jsonArray --drop
